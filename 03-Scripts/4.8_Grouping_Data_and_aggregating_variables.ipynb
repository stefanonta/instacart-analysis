# %%
import pandas as pd
import numpy as np
from os import path as pth

# %%
path = r'/Users/polusa/Library/Mobile Documents/com~apple~CloudDocs/my_DA_2024/CareerFoundry_Data_Analytics_Bootcamp/4-Python_Fundamentals_for_DA/04-2024_Instacart_Basket_Analysis/02-Data'
prepared_data_folder = r'02-Prepared_Data'
raw_data_folder = r'01-Raw_Data'

# %%
ords_prods_merge = pd.read_pickle(pth.join(path, prepared_data_folder, 'ords_prods_merge_4.7.pkl'))
ords_prods_merge.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1        26       33120                  5          0   153404             2
# 2       120       33120                 13          0    23750            11
# 3       327       33120                  5          1    58707            21
# 4       390       33120                 28          1   166654            48
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                   5                  9                    8.0
# 1                   0                 16                    7.0
# 2                   6                  8                   10.0
# 3                   6                  9                    8.0
# 4                   0                 12                    9.0
#
#          product_name  aisle_id  department_id  prices price_label  \
# 0  Organic Egg Whites        86             16    11.3   Mid-Range
# 1  Organic Egg Whites        86             16    11.3   Mid-Range
# 2  Organic Egg Whites        86             16    11.3   Mid-Range
# 3  Organic Egg Whites        86             16    11.3   Mid-Range
# 4  Organic Egg Whites        86             16    11.3   Mid-Range
#
#    busiest_days busiest_period_of_day
# 0  regular_days        average_orders
# 1  busiest_days           most_orders
# 2  regular_days        average_orders
# 3  regular_days        average_orders
# 4  busiest_days           most_orders

# %%
# import a subset (first 1_000_000 rows) of the dataset ords_prods_merge
df = ords_prods_merge[:1_000_000]
df.shape
# Out:
# (1000000, 16)

# %%
# check if the import looks ok
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1        26       33120                  5          0   153404             2
# 2       120       33120                 13          0    23750            11
# 3       327       33120                  5          1    58707            21
# 4       390       33120                 28          1   166654            48
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                   5                  9                    8.0
# 1                   0                 16                    7.0
# 2                   6                  8                   10.0
# 3                   6                  9                    8.0
# 4                   0                 12                    9.0
#
#          product_name  aisle_id  department_id  prices price_label  \
# 0  Organic Egg Whites        86             16    11.3   Mid-Range
# 1  Organic Egg Whites        86             16    11.3   Mid-Range
# 2  Organic Egg Whites        86             16    11.3   Mid-Range
# 3  Organic Egg Whites        86             16    11.3   Mid-Range
# 4  Organic Egg Whites        86             16    11.3   Mid-Range
#
#    busiest_days busiest_period_of_day
# 0  regular_days        average_orders
# 1  busiest_days           most_orders
# 2  regular_days        average_orders
# 3  regular_days        average_orders
# 4  busiest_days           most_orders

# %% [markdown]
# ### Group By and Aggregation
#
# There are essentially two steps involved when we need to group by and aggregate in pandas.
# __Group By__ refers to the action of putting together those elements that are indentical within a column. It can be applied to qualitative (most common) and also quantitative data.
#
# __Aggregation__ requires two arguments, the column that contains the quantitative data for which we want to calculate aggregation, and the type of aggregation we want to apply.
# We can additionally specify a name for a new column to create that will hold the aggregated information.

# %%
# group by department_id and calculate the average number of order, and total number of orders, for each departmnet. 
df.groupby('department_id').agg({'order_number':['mean','sum']})
# Out:
#               order_number
#                       mean       sum
# department_id
# 3                14.898875    206558
# 4                18.847057  15109120
# 7                16.462291    533691
# 11               17.419048      1829
# 12               19.215747    323132
# 13               16.473586    184916
# 14               13.120454     85506
# 16               18.867191   1905058
# 19               14.369608    235834

# %% [markdown]
# The result above shows that the department with id 4 sells on average much more than the departmet with id 14. While this seems cut and clear, it would be useful to run an hypothesis test for the mean of two samples to verify that the difference is statistically significant.

# %%
# when using standard aggregation function we can use a short version:
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 3     14.898875
# 4     18.847057
# 7     16.462291
# 11    17.419048
# 12    19.215747
# 13    16.473586
# 14    13.120454
# 16    18.867191
# 19    14.369608
# Name: order_number, dtype: float64

# %% [markdown]
# #### Applying multiple statistics, for example like `min` `max`, at once

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 3                14.898875   1  99
# 4                18.847057   1  99
# 7                16.462291   1  99
# 11               17.419048   1  71
# 12               19.215747   1  99
# 13               16.473586   1  99
# 14               13.120454   1  99
# 16               18.867191   1  99
# 19               14.369608   1  99

# %% [markdown]
# After you’ve grouped and aggregated your data, it’s time to create flags for that data. In this example, you’ll be creating a loyalty flag column in your `ords_prods_merge` dataframe.
#
# To create your flag, you’ll need some criteria. You can use the following:
#
# - If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# - If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# - If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %% [markdown]
# #### `agg()` VS `transform()`
#
# The main difference is that `agg()` reduces the dataframe size while `transform()` doesn't change the original size of it.
# Imagine the `agg()` function as a way to create the equivalent of an excel pivot table.
#
# Explanation:
#
# The `agg()` function is used to calculate a summary statistic of groups of data defined in the `groupby()` function. The resulting dataframe is smaller as data were aggregated.
#
# The `transform()` function is also used to calculate summary statistic, but it doesn't aggregate, it just "puts" the calculated statistic in each row leaving the original df size intact.

# %%
# Split the data into groups based on the “user_id” column
df.groupby('user_id')

# %%
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user
df.groupby('user_id')['order_number'].transform('max')
#ords_prods_merge.groupby('user_id')['order_number'].transform(np.max) here you can use the max function from the numpy library
# Out:
# 0          8
# 1         32
# 2         11
# 3         30
# 4         62
#           ..
# 999995    38
# 999996    20
# 999997    18
# 999998    17
# 999999    96
# Name: order_number, Length: 1000000, dtype: int64

# %%
# let's save the result in a new column
df['max_order'] = df.groupby('user_id')['order_number'].transform('max')
# Out:
# /var/folders/tj/gq9397w57h9_8h1v6ssn7y6w0000gn/T/ipykernel_14812/2175453409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_order'] = df.groupby('user_id')['order_number'].transform('max')

# %%
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1        26       33120                  5          0   153404             2
# 2       120       33120                 13          0    23750            11
# 3       327       33120                  5          1    58707            21
# 4       390       33120                 28          1   166654            48
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                   5                  9                    8.0
# 1                   0                 16                    7.0
# 2                   6                  8                   10.0
# 3                   6                  9                    8.0
# 4                   0                 12                    9.0
#
#          product_name  aisle_id  department_id  prices price_label  \
# 0  Organic Egg Whites        86             16    11.3   Mid-Range
# 1  Organic Egg Whites        86             16    11.3   Mid-Range
# 2  Organic Egg Whites        86             16    11.3   Mid-Range
# 3  Organic Egg Whites        86             16    11.3   Mid-Range
# 4  Organic Egg Whites        86             16    11.3   Mid-Range
#
#    busiest_days busiest_period_of_day  max_order
# 0  regular_days        average_orders          8
# 1  busiest_days           most_orders         32
# 2  regular_days        average_orders         11
# 3  regular_days        average_orders         30
# 4  busiest_days           most_orders         62

# %%
# change the max number of rows jupyter can display
pd.options.display.max_rows = None

# %%
df.sort_values('user_id', ascending=True).head(20)
# Out:
#         order_id  product_id  add_to_cart_order  reordered  user_id  \
# 901005   2398795       13176                  4          0        1
# 682851    431534       13176                  8          1        1
# 181401   1199898       33754                 13          0        2
# 185909   1718559       33754                 10          1        2
# 183113   1402090       33754                  8          1        2
# 178263    839880       33754                  8          1        2
# 198845   3186735       33754                 15          1        2
# 875405   2168274       13176                 12          0        2
# 169859   2037211        1819                  1          0        3
# 465029   3002854       21903                  3          1        3
# 382650   1839752       21903                  3          1        3
# 349523   1374495       21903                  7          0        3
# 169802   1972919        1819                  5          1        3
# 480929   3225766       21903                  5          1        3
# 444289   2710558       21903                  7          1        3
# 289472    521107       21903                  3          1        3
# 495550   1374495       17668                  2          0        3
# 351477   1402502       21903                  4          1        3
# 169705   1839752        1819                  2          1        3
# 496362   2710558       17668                  3          1        3
#
#         order_number  orders_day_of_week  order_hour_of_day  \
# 901005             2                   3                  7
# 682851             5                   4                 15
# 181401             6                   2                  9
# 185909             9                   2                  9
# 183113            11                   1                 10
# 178263            14                   3                 10
# 198845            12                   1                  9
# 875405             1                   2                 11
# 169859             4                   2                 18
# 465029             3                   3                 16
# 382650             7                   0                 15
# 349523             1                   1                 14
# 169802             6                   0                 16
# 480929             8                   0                 17
# 444289             5                   0                 17
# 289472            11                   0                 18
# 495550             1                   1                 14
# 351477            12                   1                 15
# 169705             7                   0                 15
# 496362             5                   0                 17
#
#         days_since_last_order  \
# 901005                   15.0
# 682851                   28.0
# 181401                   13.0
# 185909                    8.0
# 183113                   30.0
# 178263                   13.0
# 198845                   28.0
# 875405                   -1.0
# 169859                   20.0
# 465029                   21.0
# 382650                    7.0
# 349523                   -1.0
# 169802                    7.0
# 480929                    7.0
# 444289                   12.0
# 289472                   11.0
# 495550                   -1.0
# 351477                   15.0
# 169705                    7.0
# 496362                   12.0
#
#                                              product_name  aisle_id  \
# 901005                             Bag of Organic Bananas        24
# 682851                             Bag of Organic Bananas        24
# 181401  Total 2% with Strawberry Lowfat Greek Strained...       120
# 185909  Total 2% with Strawberry Lowfat Greek Strained...       120
# 183113  Total 2% with Strawberry Lowfat Greek Strained...       120
# 178263  Total 2% with Strawberry Lowfat Greek Strained...       120
# 198845  Total 2% with Strawberry Lowfat Greek Strained...       120
# 875405                             Bag of Organic Bananas        24
# 169859           All Natural No Stir Creamy Almond Butter        88
# 465029                               Organic Baby Spinach       123
# 382650                               Organic Baby Spinach       123
# 349523                               Organic Baby Spinach       123
# 169802           All Natural No Stir Creamy Almond Butter        88
# 480929                               Organic Baby Spinach       123
# 444289                               Organic Baby Spinach       123
# 289472                               Organic Baby Spinach       123
# 495550    Unsweetened Chocolate Almond Breeze Almond Milk        91
# 351477                               Organic Baby Spinach       123
# 169705           All Natural No Stir Creamy Almond Butter        88
# 496362    Unsweetened Chocolate Almond Breeze Almond Milk        91
#
#         department_id  prices price_label  busiest_days busiest_period_of_day  \
# 901005              4    10.3   Mid-Range  slowest_days        average_orders
# 682851              4    10.3   Mid-Range  slowest_days           most_orders
# 181401             16    11.8   Mid-Range  regular_days        average_orders
# 185909             16    11.8   Mid-Range  regular_days        average_orders
# 183113             16    11.8   Mid-Range  busiest_days           most_orders
# 178263             16    11.8   Mid-Range  slowest_days           most_orders
# 198845             16    11.8   Mid-Range  busiest_days        average_orders
# 875405              4    10.3   Mid-Range  regular_days           most_orders
# 169859             13    11.5   Mid-Range  regular_days        average_orders
# 465029              4     8.2   Mid-Range  slowest_days           most_orders
# 382650              4     8.2   Mid-Range  busiest_days           most_orders
# 349523              4     8.2   Mid-Range  busiest_days           most_orders
# 169802             13    11.5   Mid-Range  busiest_days           most_orders
# 480929              4     8.2   Mid-Range  busiest_days        average_orders
# 444289              4     8.2   Mid-Range  busiest_days        average_orders
# 289472              4     8.2   Mid-Range  busiest_days        average_orders
# 495550             16     6.6   Mid-Range  busiest_days           most_orders
# 351477              4     8.2   Mid-Range  busiest_days           most_orders
# 169705             13    11.5   Mid-Range  busiest_days           most_orders
# 496362             16     6.6   Mid-Range  busiest_days        average_orders
#
#         max_order
# 901005          5
# 682851          5
# 181401         14
# 185909         14
# 183113         14
# 178263         14
# 198845         14
# 875405         14
# 169859         12
# 465029         12
# 382650         12
# 349523         12
# 169802         12
# 480929         12
# 444289         12
# 289472         12
# 495550         12
# 351477         12
# 169705         12
# 496362         12

# %% [markdown]
# #### Deriving Columns with `loc()`
#
# With your new column ready to go, all that’s left is to create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value

# %%
# function to calculate level of loyalty
def loyalty_level(num_of_orders):
    if num_of_orders <= 10: return 'new customer'
    elif num_of_orders <= 40: return 'regular customer'
    elif num_of_orders > 40: return 'loyal customer'
    else: return 'loyalty level not found '

# %%
df['loyalty_flag'] = df['max_order'].apply(loyalty_level)
# Out:
# /var/folders/tj/gq9397w57h9_8h1v6ssn7y6w0000gn/T/ipykernel_14812/1820539274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loyalty_flag'] = df['max_order'].apply(loyalty_level)

# %%
# df.loc[df['order_max'] <= 10, 'loyalty_flag'] = 'new_customer'
# df.loc[(df['order_max'] > 10) & (df['order_max'] <= 40), 'loyalty_flag'] = 'regular_customer'
# df.loc[df['order_max'] > 40, 'loyalty_flag'] = 'loyal_customer'

# %%
df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         2       33120                  1          1   202279             3
# 1        26       33120                  5          0   153404             2
# 2       120       33120                 13          0    23750            11
# 3       327       33120                  5          1    58707            21
# 4       390       33120                 28          1   166654            48
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  \
# 0                   5                  9                    8.0
# 1                   0                 16                    7.0
# 2                   6                  8                   10.0
# 3                   6                  9                    8.0
# 4                   0                 12                    9.0
#
#          product_name  aisle_id  department_id  prices price_label  \
# 0  Organic Egg Whites        86             16    11.3   Mid-Range
# 1  Organic Egg Whites        86             16    11.3   Mid-Range
# 2  Organic Egg Whites        86             16    11.3   Mid-Range
# 3  Organic Egg Whites        86             16    11.3   Mid-Range
# 4  Organic Egg Whites        86             16    11.3   Mid-Range
#
#    busiest_days busiest_period_of_day  max_order      loyalty_flag
# 0  regular_days        average_orders          8      new customer
# 1  busiest_days           most_orders         32  regular customer
# 2  regular_days        average_orders         11  regular customer
# 3  regular_days        average_orders         30  regular customer
# 4  busiest_days           most_orders         62    loyal customer

# %%
df['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# regular customer    466784
# loyal customer      329051
# new customer        204165
# Name: count, dtype: int64

# %%
df[['user_id', 'max_order', 'loyalty_flag']].sort_values('max_order', ascending=False).head(60)
# Out:
#         user_id  max_order    loyalty_flag
# 935701   121860         99  loyal customer
# 546537   119835         99  loyal customer
# 219766   172294         99  loyal customer
# 546593   191820         99  loyal customer
# 320521   112044         99  loyal customer
# 546615   172806         99  loyal customer
# 546620    44182         99  loyal customer
# 997476    38720         99  loyal customer
# 546657     5449         99  loyal customer
# 219720     8664         99  loyal customer
# 546684   191755         99  loyal customer
# 898590   119835         99  loyal customer
# 546691   182630         99  loyal customer
# 219683    61899         99  loyal customer
# 546718    20965         99  loyal customer
# 546731   194449         99  loyal customer
# 546742    41996         99  loyal customer
# 546746    74680         99  loyal customer
# 546749   121860         99  loyal customer
# 898608    16290         99  loyal customer
# 546535    47644         99  loyal customer
# 546772    55935         99  loyal customer
# 898617    23744         99  loyal customer
# 220019    23405         99  loyal customer
# 546289    55935         99  loyal customer
# 546295    51309         99  loyal customer
# 381906   130036         99  loyal customer
# 957949   156475         99  loyal customer
# 546323     5449         99  loyal customer
# 381891   194017         99  loyal customer
# 546357   112044         99  loyal customer
# 898646    11845         99  loyal customer
# 546372   184451         99  loyal customer
# 546395   197909         99  loyal customer
# 219928    77311         99  loyal customer
# 546439   182630         99  loyal customer
# 898622    49210         99  loyal customer
# 546456    48969         99  loyal customer
# 219920    69173         99  loyal customer
# 381848   142245         99  loyal customer
# 381809    54594         99  loyal customer
# 381798    85247         99  loyal customer
# 547417   121327         99  loyal customer
# 958023   143352         99  loyal customer
# 219435   145052         99  loyal customer
# 547190   105213         99  loyal customer
# 219412    54594         99  loyal customer
# 547227   170096         99  loyal customer
# 547246    82598         99  loyal customer
# 14255     66500         99  loyal customer
# 547263   100629         99  loyal customer
# 14253     89799         99  loyal customer
# 547268   121327         99  loyal customer
# 547296    85247         99  loyal customer
# 219329   156475         99  loyal customer
# 958065    18412         99  loyal customer
# 219282   145052         99  loyal customer
# 547358    48969         99  loyal customer
# 547378    26715         99  loyal customer
# 219267   143352         99  loyal customer

# %% [markdown]
# Let's verify the distribution of the "loyalty_flag" variable

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# regular customer    466784
# loyal customer      329051
# new customer        204165
# Name: count, dtype: int64

# %%
# Out:
# dtype('O')
